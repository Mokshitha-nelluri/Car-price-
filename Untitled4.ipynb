# %%
import pandas as pd
import numpy as np
car = pd.read_csv('C:\\Users\\moksh\\OneDrive\\Desktop\\carprice.csv')
car.shape
car.info()
car['symboling'].unique()
car['CarName'].unique()
car['fueltype'].unique()

categorical_cols = [
    "symboling", "CarName", "fueltype", "aspiration",
    "doornumber", "carbody", "drivewheel", "enginelocation",
    "enginetype", "cylindernumber", "fuelsystem"
]

car= pd.get_dummies(car, columns=categorical_cols, drop_first=True)


numeric_cols = [
    "wheelbase", "carlength", "carwidth", "carheight", "curbweight",
    "enginesize", "boreratio", "stroke", "compressionratio",
    "horsepower", "peakrpm", "citympg", "highwaympg", "price"
]

for col in numeric_cols:
    car[col] = (car[col] - car[col].min()) / (car[col].max() - car[col].min())

# Separate Features and Target Variable
X = car.drop(columns=["price"])
y = car["price"]
#multivariable regression
def initialize_parameters(X):
    m, n = X.shape
    parameters = {
        'm': np.random.rand(n),
        'c': np.random.rand()
    }
    return parameters


def forward_propagation(X, parameters):
    m = parameters['m']
    c = parameters['c']
    predictions = np.dot(X, m) + c
    return predictions


def mean_squared_error(predictions, y):
    return np.mean((predictions - y) ** 2)


def gradient_descent(X, y, parameters, learning_rate):
    m = parameters['m']
    c = parameters['c']
    predictions = forward_propagation(X, parameters)
    if np.isnan(predictions).any():
        raise ValueError("NaN values encountered in predictions. Check your data.")
    if np.isclose(np.dot(X.T, error), 0.0):
        raise ValueError("Division by zero in gradient descent. Check your data or learning rate.")
    error = y - predictions
    epsilon = 1e-10
    dm = -2 * np.dot(X.T, error) / (len(y) + epsilon)
    dc = -2 * np.sum(error) / (len(y) + epsilon)
    m = m - learning_rate * dm
    c = c - learning_rate * dc
    parameters['m'] = m
    parameters['c'] = c
    return parameters
def train_linear_regression(X, y, learning_rate, iters):
    parameters = initialize_parameters(X)
    loss = []

    for i in range(iters):
        predictions = forward_propagation(X, parameters)
        cost = mean_squared_error(predictions, y)
        loss.append(cost)
        parameters = gradient_descent(X, y, parameters, learning_rate)

    return parameters, loss

learning_rate = 0.01
iterations = 1000

trained_parameters, loss = train_linear_regression(X, y, learning_rate, iterations)
new_data_point = X.values[0]
predicted_price = forward_propagation(new_data_point, trained_parameters)
print(f'Predicted Price: {predicted_price}')
import matplotlib.pyplot as plt

slope = trained_parameters['m']
intercept = trained_parameters['c']


plt.scatter(x, y, label='Data Points', color='b')


x_values = np.linspace(np.min(x), np.max(x), 100)


y_values = slope * x_values + intercept


plt.plot(x_values, y_values, label='Linear Regression Line', color='r')


plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.legend()


plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...
